# %% [markdown]
# Using data from [UCSUSA's satellite database](https://www.ucsusa.org/resources/satellite-database), specifically [UCS-Satellite-Database-8-1-2020.txt](https://www.ucsusa.org/sites/default/files/2020-10/UCS-Satellite-Database-8-1-2020.txt), to allow filtering of satellites for a subsequent hit detection stage.

# %%
import pandas as pd
df = pd.read_csv("UCS-Satellite-Database-8-1-2020.txt", sep='\t', encoding='L1', low_memory=False) 
df = df.dropna(axis='columns',how='all')
df
# Out:
#                      Name of Satellite, Alternate Names  \
# 0     1HOPSAT-TD (1st-generation High Optical Perfor...
# 1                                                3Cat-1
# 2                                              Aalto-1
# 3                                              AAUSat-4
# 4                              ABS-2 (Koreasat-8, ST-3)
# ...                                                 ...
# 2785                                         Ziyuan 3-2
# 2786                                         Ziyuan 3-3
# 2787                                                NaN
# 2788                                                NaN
# 2789                                                NaN
#
#      Current Official Name of Satellite Country/Org of UN Registry  \
# 0                               1HOPSAT                  NR (3/20)
# 1                                3Cat-1                         NR
# 2                               Aalto-1                    Finland
# 3                              AAUSat-4                    Denmark
# 4                                 ABS-2                         NR
# ...                                 ...                        ...
# 2785                         Ziyuan 3-2                      China
# 2786                         Ziyuan 3-3                  NR (7/20)
# 2787                                NaN                        NaN
# 2788                                NaN                        NaN
# 2789                                NaN                        NaN
#
#      Country of Operator/Owner  \
# 0                          USA
# 1                        Spain
# 2                      Finland
# 3                      Denmark
# 4                Multinational
# ...                        ...
# 2785                     China
# 2786                     China
# 2787                       NaN
# 2788                       NaN
# 2789                       NaN
#
#                                          Operator/Owner       Users  \
# 0                                          Hera Systems  Commercial
# 1                  Universitat Politècnica de Catalunya       Civil
# 2                                      Aalto University       Civil
# 3                                 University of Aalborg       Civil
# 4                         Asia Broadcast Satellite Ltd.  Commercial
# ...                                                 ...         ...
# 2785  China Centre for Resources Satellite Data and ...  Government
# 2786  China Centre for Resources Satellite Data and ...  Government
# 2787                                                NaN         NaN
# 2788                                                NaN         NaN
# 2789                                                NaN         NaN
#
#                      Purpose                       Detailed Purpose  \
# 0          Earth Observation                 Technology Development
# 1     Technology Development                                    NaN
# 2     Technology Development                                    NaN
# 3          Earth Observation  Automatic Identification System (AIS)
# 4             Communications                                    NaN
# ...                      ...                                    ...
# 2785       Earth Observation                                    NaN
# 2786       Earth Observation                                    NaN
# 2787                     NaN                                    NaN
# 2788                     NaN                                    NaN
# 2789                     NaN                                    NaN
#
#      Class of Orbit       Type of Orbit  ...               Unnamed: 31  \
# 0               LEO  Non-Polar Inclined  ...  https://www.herasys.com/
# 1               LEO                 NaN  ...                       NaN
# 2               LEO                 NaN  ...                       NaN
# 3               LEO     Sun-Synchronous  ...                       NaN
# 4               GEO                 NaN  ...                       NaN
# ...             ...                 ...  ...                       ...
# 2785            LEO     Sun-Synchronous  ...                       NaN
# 2786            LEO     Sun-Synchronous  ...                       NaN
# 2787            NaN                 NaN  ...                       NaN
# 2788            NaN                 NaN  ...                       NaN
# 2789            NaN                 NaN  ...                       NaN
#
#                                                Source.1  \
# 0                                                   NaN
# 1                                                   NaN
# 2        http://www.planet4589.org/space/log/satcat.txt
# 3     http://space50.org/objekt.php?mot=2016-025E&ja...
# 4     http://www.zarya.info/Diaries/Launches/Launche...
# ...                                                 ...
# 2785    https://www.planet4589.org/space/log/satcat.txt
# 2786       http://www.lib.cas.cz/space.40/2011/079A.HTM
# 2787    https://www.planet4589.org/space/log/satcat.txt
# 2788  http://www.nasaspaceflight.com/2012/01/china-o...
# 2789                  http://spaceflights.news/?p=35647
#
#                                                Source.2  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     http://www.absatellite.net/2010/10/13/asia-bro...
# ...                                                 ...
# 2785  http://space50.org/objekt.php?mot=2016-033A&ja...
# 2786                                                NaN
# 2787                                                NaN
# 2788                                                NaN
# 2789                                                NaN
#
#                                                Source.3  Source.4 Source.5  \
# 0                                                   NaN       NaN      NaN
# 1                                                   NaN       NaN      NaN
# 2                                                   NaN       NaN      NaN
# 3                                                   NaN       NaN      NaN
# 4     http://www.spacenews.com/article/satellite-tel...       NaN      NaN
# ...                                                 ...       ...      ...
# 2785                                                NaN       NaN      NaN
# 2786                                                NaN       NaN      NaN
# 2787                                                NaN       NaN      NaN
# 2788                                                NaN       NaN      NaN
# 2789                                                NaN       NaN      NaN
#
#      Unnamed: 60 Unnamed: 61 Unnamed: 62 Unnamed: 66
# 0            NaN         NaN         NaN         NaN
# 1            NaN         NaN         NaN         NaN
# 2            NaN         NaN         NaN         NaN
# 3            NaN         NaN         NaN         NaN
# 4            NaN         NaN         NaN         NaN
# ...          ...         ...         ...         ...
# 2785         NaN         NaN         NaN         NaN
# 2786         NaN         NaN         NaN         NaN
# 2787         NaN         NaN         NaN         NaN
# 2788         NaN         NaN         NaN         NaN
# 2789         NaN         NaN         NaN         NaN
#
# [2790 rows x 41 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2790 entries, 0 to 2789
# Data columns (total 41 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Name of Satellite, Alternate Names  2787 non-null   object
#  1   Current Official Name of Satellite  2787 non-null   object
#  2   Country/Org of UN Registry          2787 non-null   object
#  3   Country of Operator/Owner           2787 non-null   object
#  4   Operator/Owner                      2787 non-null   object
#  5   Users                               2787 non-null   object
#  6   Purpose                             2787 non-null   object
#  7   Detailed Purpose                    797 non-null    object
#  8   Class of Orbit                      2787 non-null   object
#  9   Type of Orbit                       2162 non-null   object
#  10  Longitude of GEO (degrees)          2787 non-null   float64
#  11  Perigee (km)                        2787 non-null   object
#  12  Apogee (km)                         2787 non-null   object
#  13  Eccentricity                        2787 non-null   float64
#  14  Inclination (degrees)               2787 non-null   float64
#  15  Period (minutes)                    2787 non-null   object
#  16  Launch Mass (kg.)                   2580 non-null   object
#  17  Dry Mass (kg.)                      443 non-null    object
#  18  Power (watts)                       603 non-null    object
#  19  Date of Launch                      2787 non-null   object
#  20  Expected Lifetime (yrs.)            1148 non-null   float64
#  21  Contractor                          2787 non-null   object
#  22  Country of Contractor               2787 non-null   object
#  23  Launch Site                         2787 non-null   object
#  24  Launch Vehicle                      2787 non-null   object
#  25  COSPAR Number                       2787 non-null   object
#  26  NORAD Number                        2787 non-null   float64
#  27  Comments                            1412 non-null   object
#  28  Unnamed: 28                         4 non-null      object
#  29  Source Used for Orbital Data        2580 non-null   object
#  30  Source                              2299 non-null   object
#  31  Unnamed: 31                         87 non-null     object
#  32  Source.1                            1542 non-null   object
#  33  Source.2                            726 non-null    object
#  34  Source.3                            279 non-null    object
#  35  Source.4                            83 non-null     object
#  36  Source.5                            18 non-null     object
#  37  Unnamed: 60                         3 non-null      object
#  38  Unnamed: 61                         3 non-null      object
#  39  Unnamed: 62                         2 non-null      object
#  40  Unnamed: 66                         2 non-null      object
# dtypes: float64(5), object(36)
# memory usage: 893.8+ KB

# %% [markdown]
# The full list of satellites is unwieldy for selecting a single satellite, so first we'll group them into a few hundred shared prefixes, which for a constellation of objects like "Amos 3, Amos 4, Amos 17" would be the shared name "Amos".

# %%
satellites = list(df.iloc[:, 1].unique())
satellites

import re
constellations = sorted(list(set([re.sub(r'[ -].*', '', str(s)) for s in satellites])))
print(len(constellations), ", ".join(constellations))
# Out:
# 646 1HOPSAT, 3Cat, AAUSat, ABS, AIM, AISSat, AIST, AISTechSat, AISat, ALE, ALiCE, AMC, ANASIS, ANDESITE, ANGELS, ARMADILLO, ASNARO, AT&T, ATL, Aalto, Aeneas, Aeolus, Aerocube, Al, AlSat, Alcomsat, Alsat, AmGU, Amazonas, Amos, Amsat, Anik, Aoba, AprizeSat, Apstar, Aqua, ArSat, Arabsat, Arkyd, AsiaSat, AsiaStar, Astra, Astranis, Astrocast, Astrosat, Athena, Athenoxat, Aura, Aurora, Azerspace, AztecSat, BDSAGR, BIROS, BKA, BRIO, BRISat, BRITE, BRO, BSAT, Badr, Bangabandhu, Beesat, Beidou, BeijinGalaxy, Belintersat, Bhutan, BisonSat, Bispectral, BlackSky, Bluewalker, Brazilsat, BricSat, Buccaneer, Bufeng, Bugsat, BulgariaSat, CATSat, CBERS, CBNT, CE, CELTEE, CFESat, CFOSat, CHEOPS, CHOMPTT, CINEMA, COMS, COMSATBw, CORVUS, COSMIC, COSMO, CP, CSG, CSIM, CSO, CYGNSS, CYNGSS, Calipso, CanX, Canopus, Capella, CartoSat, Cassiope, CeReS, Centauri, Centispace, Chafsat, Chandra, Changshagaoxin, Chao, Chefsat, Chuangxin, ChubuSat, CiRiS, Cicero, Ciel, Cloudsat, Compass, Condor, Coriolis, Cosmos, Cosmos2538, CryoCube, Cryosat, CubeRRT, Cubebug, Cubesail, Cubesat, D, DAMPE, DAVE, DCBB, DHFR, DLR, DMC, DSX, DX, DaVinci, Daichi, Data, DeMi, Deimos, Delfi, Delfini, Dellingr, Diamond, Dido, DirecTV, Diwata, DoT, Dove, DubaiSat, Duchifat, E, EDRS, ELFIN, ELISA, EMISat, ERG, EROS, ESEO, ETRSS, Eagle, Eaglet, EcAMSat, Echostar, Ecuador, EgyptSat, El, Electro, EquiSat, Es'hail, Eu:CROPIS, Eutelsat, Eutensat, ExSeedSat, Exoconnect, Express, Eyesat, FACSAT, FLP, FUNCube, Falconsat, Fast, Fengmaniu, Fengniao, Fengyun, Fermi, Firebird, FloripaSat, FormoSat, Fossasat, Fox, G, GATOSS, GCOM, GEARRSAT, GEO, GHGSat, GOES, GOSAT, GPIM, GPM, GRIFEX, GRUS, GSAT, Galaxy, Galileo, Gaofen, Genesis, GeoEye, Geomagnetic, Globalstar, GomX, Gonets, GovSat, Grace, Göktürk, HEAD, HJ, HSAT, HXMT, HYLAS, Haiyang, HaloSat, Hawk, Helios, Hellas, HellasSat, Hiber, Himawari, Hinode, Hisaki, Hispasat, Hodoyoshi, Hongyan, Hongyun, Horizons, Horyu, Huangpu, Hubble, Huia'an, Huskysat, HySIS, ICEYE, ICON, IGS, INMARSAT, INNOSat, INS, INSAT, INTErnational, IOD, IRIS, IRNSS, IRS, ISARA, ISX, ITU, Ibuki, Icesat, Intelsat, International, Interstellar, Iridium, Iridum, Iriidium, Irvine, JAISAT, JCSat, JCSat18/Kacific, JYISat, Jason, Jiading, Jilin, Jingshi, KIPP, KJSY, KKS, KL, KX, Kaituo, Kanopus, KazEOSat, KazSTSAT, KazSat, KazSciSat, Kent, Kepler, KestrelEye, KhalifaSat, Kirameki, Kompsat, Koreasat, LAPAN, LEO, LKW, LQSat, Ladybird, Landmapper, Landsat, LaoSat, LatinSat, Lemur, Lemur2F69, Lemur2F74, Lemur2F76, Lemur2FM104, LightSat, Lightsail, LilacSat, Ling, Lingque, Lithuanicasat, Long, Luch, Luch/Olympus, Lucky, Lume, Luojia, M, M3MSat, MEV, MINXSS, MMS, MOVE, MP6, MSAT, MTSAT, MUOS, MVL, MakerSat, Maroc, Max, Maya, Measat, Megha, Merah, Meridian, Meshbed, MetOp, Meteor, Meteosat, Mexsat, MicroDragon, MicroMAS, Microsat, Microvariability, Mohammed, Mozhayets, Multispectral, N, NARSSCUBE, NEOSSat, NIUSat, NOAA, NOOR, NPP, NPSat, NSLSat, NSS, NUDTSat, NanoACE, Nanosat, Naxing, Nayif, NepaliSat, NextSat, Nexus, NigComSat, NigeriaSat, Nigeriasat, Nilesat, Nimiq, Ningxia, NorSat, NovaSAR, NuSTAR, Nusantara, O3b, OCO, OHS, OPS, OPTOS, ORBCOMM, ORCA, ORS, OTB, OVS, Oculus, Odin, Ofeq, OneWeb, Optsat, Optus, Orbital, Orbweaver, PEASSS, PISAT, PRISMA, PRSS, PWSat, Painani, PakTES, Paksat, Palapa, Palisade, ParkinsonSat, Pathfinder, Paz, Pearl, Pegasus, Perseus, PeruSat, Pléiades, Polar, PolyITAN, Proba, Prometheus, PropCube, Prototype, Prox, Proxima, Pujiang, QARMAN, QPS, QSS, QZS, Qiancheng, Qsat, Quetzal, QueztSat, R3D2, RAAF, RANGE, RAPIS, RASAT, RAVAN, RBSP, RCM, RHESSI, RISESAT, RISat, RSat, Raavana, RadFxSat, Radarsat, Radio, Radsat, Raduga, RainCube, Rascom, Reaktor, Red, Reimei, Relek, RemoveDebris, Resourcesat, Resurs, Rising, Robusta, Rumba, S, SAOCOM, SAR, SARAL, SCD, SDO, SDS, SEEDS, SES, SGDC, SHFT, SINOD, SMAP, SMDC, SMOG, SMOS, SNUGLITE, SNUSat, SNaP, SOCRATES, SOHLA, SOKRAT, SONATE, SORTIE, SOlar, SPARC, SPATIUM, SPIRALE, SPROUT, SRMSat, SSOT, SSRS, SSTL, ST, STF, STPSat, S ...

# %%
import panel as pn, panel.widgets as pnw
pn.extension()

constellation = pnw.Select(options=constellations, name="Constellation")
constellation
# Out:
# Select(name='Constellation', options=['1HOPSAT', '3Cat', ...], value='1HOPSAT')

# %%
satellite = pnw.Select(options=[s for s in satellites if re.match(constellation.value, str(s))], name="Satellite")
satellite
# Out:
# Select(name='Satellite', options=['Amos 17', 'Amos 3', ...], value='Amos 17')
