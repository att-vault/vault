# %% [markdown]
# This is a quick example of how to use the precomputed Satellite trajectory store

# %%
from datetime import datetime
import sathelpers

# %%
# Load up the cached file
index_path = "/data/Indexed_TLE/index"

sdr = sathelpers.SatelliteDataStore(index_path)
all_ids = sdr.get_norad_ids()

print("Precomputed index stores %i items" % len(all_ids))
# Out:
# Precomputed index stores 19404 items

# %%
# Pull timeseries from 10 days for a few randomly chosen satellites
import random

for x in range(10):
    random_norad_id = all_ids[random.randint(0, len(all_ids))]
    print(random_norad_id, sdr.get_timespan(random_norad_id))
    t, lat, long, dist = sdr.get_precomputed_tracks(random_norad_id, datetime(2016, 1, 10), datetime(2016, 1, 11))
# Out:
# 745 (datetime.datetime(2008, 12, 18, 20, 5, 20), datetime.datetime(2017, 2, 14, 18, 8))
# 31559 (datetime.datetime(2008, 12, 19, 11, 44), datetime.datetime(2017, 2, 13, 14, 13, 20))
# 29836 (datetime.datetime(2008, 12, 18, 9, 59, 28), datetime.datetime(2017, 2, 14, 12, 22, 24))
# 30871 (datetime.datetime(2008, 12, 18, 0, 51, 12), datetime.datetime(2017, 2, 14, 20, 58, 40))
# 37027 (datetime.datetime(2010, 12, 24, 19, 37, 36), datetime.datetime(2012, 1, 7, 20, 3, 12))
# 38977 (datetime.datetime(2012, 12, 18, 4, 20, 16), datetime.datetime(2017, 2, 14, 18, 33, 36))
# 24978 (datetime.datetime(2008, 12, 18, 16, 44, 48), datetime.datetime(2017, 2, 14, 8, 27, 44))
# 28318 (datetime.datetime(2008, 12, 18, 23, 25, 52), datetime.datetime(2017, 2, 14, 6, 53, 52))
# 28446 (datetime.datetime(2008, 12, 18, 9, 6, 8), datetime.datetime(2017, 2, 14, 15, 0, 16))
# 38086 (datetime.datetime(2012, 2, 14, 15, 0, 16), datetime.datetime(2016, 2, 14, 21, 13, 36))

# %%
# Plot them!
from pylab import plot

# %%
plot(t, lat)
plot(t, long)
