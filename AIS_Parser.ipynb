# %% [markdown]
# ## AIS Parser
# * Prerequisite: Install gdal library/tool for GDB Parser
# ** brew install gdal
# * Prerequisite: command to Convert GDB into CSV
# ** ogr2ogr -f CSV output.csv ./Zone1_2009_01.gdb -lco GEOMETRY=AS_XYZ
# * Parse the 2015-2017 flat csv and transform data into Vessel, Broadcast, and Voyage files to be uniform with the GDB Exported Data
# * Rename all the columns to a unified naming convention and select only the common attributes across all zones/years

# %%
# from IPython.display import Image, HTML
import os
import numpy as np
import pandas as pd
import datetime
import warnings

warnings.filterwarnings("ignore")           # Suppress Warning

# %%
# https://afdata.s3.us-gov-west-1.amazonaws.com/index.html#Scenario_Data/
# Prerequisite: 
# Download raw data to local folder
# Unzip everything into ./csv/AIS/ Folder

WorkingFolder = "data/vessel data/"

# %% [markdown]
# ### Process Flat AIS Data

# %%
OutputDir = WorkingFolder + "AIS_Processed/Zone01_2016_01/"

if not os.path.exists(OutputDir):
    os.mkdir(OutputDir)

# %%
ais = pd.read_csv(WorkingFolder + "AIS/AIS_2016_01_Zone01.csv", sep=",")
ais.head(3)
# Out:
#         MMSI         BaseDateTime       LAT        LON  SOG  COG  Heading  \
# 0  367303490  2016-01-01T00:08:23  51.86139 -176.63799  0.1  3.6    359.0
# 1  367303490  2016-01-01T00:23:24  51.86144 -176.63798  0.0  3.6    359.0
# 2  367303490  2016-01-01T00:47:22  51.86144 -176.63799  0.1  3.6      0.0
#
#         VesselName         IMO CallSign  VesselType  Status  Length  Width  \
# 0  RESOLVE PIONEER  IMO7528843  WDD8846      1005.0  moored   63.23  12.25
# 1  RESOLVE PIONEER  IMO7528843  WDD8846      1005.0  moored   63.23  12.25
# 2  RESOLVE PIONEER  IMO7528843  WDD8846      1005.0  moored   63.23  12.25
#
#    Draft  Cargo
# 0    4.5    NaN
# 1    4.5    NaN
# 2    4.5    NaN

# %%
ais.shape
# Out:
# (21426, 16)

# %%
# ais.columns

# %%
ais.rename(columns={'MMSI':'mmsi_id', 'BaseDateTime':'date_time', 'LAT':'lat', 'LON':'lon', 'SOG':'speed_over_ground', 'COG':'course_over_ground', 'Heading':'heading', 'Status':'status', 'VesselName':'vessel_name', 'IMO':'imo', 'CallSign':'call_sign', 'VesselType':'vessel_type', 'Length':'length', 'Width':'width', 'Draft':'draft', 'Cargo':'cargo'}, inplace=True)
ais.head(3)
# Out:
#      mmsi_id            date_time       lat        lon  speed_over_ground  \
# 0  367303490  2016-01-01T00:08:23  51.86139 -176.63799                0.1
# 1  367303490  2016-01-01T00:23:24  51.86144 -176.63798                0.0
# 2  367303490  2016-01-01T00:47:22  51.86144 -176.63799                0.1
#
#    course_over_ground  heading      vessel_name         imo call_sign  \
# 0                 3.6    359.0  RESOLVE PIONEER  IMO7528843   WDD8846
# 1                 3.6    359.0  RESOLVE PIONEER  IMO7528843   WDD8846
# 2                 3.6      0.0  RESOLVE PIONEER  IMO7528843   WDD8846
#
#    vessel_type  status  length  width  draft  cargo
# 0       1005.0  moored   63.23  12.25    4.5    NaN
# 1       1005.0  moored   63.23  12.25    4.5    NaN
# 2       1005.0  moored   63.23  12.25    4.5    NaN

# %%
# Voyages got collapsed
ais['voyage_id'] = np.nan

# %%
# ais.columns

# %%
# Extract Broadcast Data
Broadcast = ais[['mmsi_id', 'date_time', 'lat', 'lon', 'speed_over_ground','course_over_ground', 'voyage_id', 'heading', 'status']]
Broadcast.head()
# Out:
#      mmsi_id            date_time       lat        lon  speed_over_ground  \
# 0  367303490  2016-01-01T00:08:23  51.86139 -176.63799                0.1
# 1  367303490  2016-01-01T00:23:24  51.86144 -176.63798                0.0
# 2  367303490  2016-01-01T00:47:22  51.86144 -176.63799                0.1
# 3  367303490  2016-01-01T01:02:23  51.86144 -176.63791                0.0
# 4  367303490  2016-01-01T01:08:21  51.86143 -176.63791                0.0
#
#    course_over_ground  voyage_id  heading  status
# 0                 3.6        NaN    359.0  moored
# 1                 3.6        NaN    359.0  moored
# 2                 3.6        NaN      0.0  moored
# 3                 3.6        NaN    359.0  moored
# 4                 3.6        NaN    359.0  moored

# %%
# Extract Vessel Data
Vessel = ais[['mmsi_id', 'imo', 'call_sign', 'vessel_name', 'vessel_type','length', 'width']].drop_duplicates()
Vessel.head()
# Out:
#        mmsi_id         imo call_sign       vessel_name  vessel_type  length  \
# 0    367303490  IMO7528843   WDD8846   RESOLVE PIONEER       1005.0   63.23
# 396  366947000  IMO8225101   WRC6707  NORTHERN GLACIER       1001.0   61.27
# 428  357058000  IMO9227601     3FWC9        NO.2 POHAH         70.0  120.00
# 523  413478230  IMO9608427      BOFD            DA XIN       1004.0  179.57
# 524  338626000  IMO8213225   WDG2215   ALASKA PROVIDER       1001.0   54.00
#
#      width
# 0    12.25
# 396  13.72
# 428  16.00
# 523  28.00
# 524  12.20

# %%
# Extract Voyage Data
Voyage = ais[['mmsi_id', 'voyage_id', 'draft', 'cargo']].drop_duplicates()
Voyage.head()
# Out:
#        mmsi_id  voyage_id  draft  cargo
# 0    367303490        NaN    4.5    NaN
# 396  366947000        NaN    5.3    NaN
# 428  357058000        NaN    5.3   70.0
# 523  413478230        NaN   10.5   70.0
# 524  338626000        NaN    3.8    NaN

# %%
# Output result to csv
Broadcast.to_csv(OutputDir + "Broadcast.csv", index=False)
Vessel.to_csv(OutputDir + "Vessel.csv", index=False)
Voyage.to_csv(OutputDir + "Voyage.csv", index=False)

# %% [markdown]
# ### Process GDB Format

# %%
GDB_Folder = WorkingFolder + "AIS/Zone10_2014_01.gdb/"
OutputDir = WorkingFolder + "AIS_Processed/Zone10_2014_01/"

if not os.path.exists(OutputDir):
    os.mkdir(OutputDir)

# %%
Broadcast = pd.read_csv(GDB_Folder + "Broadcast.csv", sep=",")
Broadcast.head(3)
# Out:
#             X          Y  Z  SOG         COG  Heading  ROT  \
# 0 -122.361145  47.581332  0  0.0   39.599998      511  128
# 1 -123.990592  45.835737  0  6.7  355.399990      359  129
# 2 -122.382117  47.631067  0  0.0  192.100010      180    0
#
#           BaseDateTime  Status  VoyageID       MMSI ReceiverType ReceiverID
# 0  2013/12/31 23:57:44       0         1  366025993            b  003669987
# 1  2013/12/31 23:57:44      15         2  367160890            b  003669987
# 2  2013/12/31 23:57:44       7         3  366490600            b  003669987

# %%
Broadcast.rename(columns={'MMSI':'mmsi_id', 'BaseDateTime':'date_time', 'Y':'lat', 'X':'lon', 'SOG':'speed_over_ground', 'COG':'course_over_ground', 'Heading':'heading', 'Status':'status', 'VoyageID':'voyage_id'}, inplace=True)
Broadcast.head(3)
# Out:
#           lon        lat  Z  speed_over_ground  course_over_ground  heading  \
# 0 -122.361145  47.581332  0                0.0           39.599998      511
# 1 -123.990592  45.835737  0                6.7          355.399990      359
# 2 -122.382117  47.631067  0                0.0          192.100010      180
#
#    ROT            date_time  status  voyage_id    mmsi_id ReceiverType  \
# 0  128  2013/12/31 23:57:44       0          1  366025993            b
# 1  129  2013/12/31 23:57:44      15          2  367160890            b
# 2    0  2013/12/31 23:57:44       7          3  366490600            b
#
#   ReceiverID
# 0  003669987
# 1  003669987
# 2  003669987

# %%
# Broadcast.shape

# %%
# Extract Broadcast Data
Broadcast = Broadcast[['mmsi_id', 'date_time', 'lat', 'lon', 'speed_over_ground','course_over_ground', 'voyage_id', 'heading', 'status']]
Broadcast.head()
# Out:
#      mmsi_id            date_time        lat         lon  speed_over_ground  \
# 0  366025993  2013/12/31 23:57:44  47.581332 -122.361145                0.0
# 1  367160890  2013/12/31 23:57:44  45.835737 -123.990592                6.7
# 2  366490600  2013/12/31 23:57:44  47.631067 -122.382117                0.0
# 3  338000406  2013/12/31 23:57:44  48.123443 -123.444115                0.0
# 4  367840001  2013/12/31 23:57:44  48.121267 -122.726412               11.4
#
#    course_over_ground  voyage_id  heading  status
# 0           39.599998          1      511       0
# 1          355.399990          2      359      15
# 2          192.100010          3      180       7
# 3           14.200000          4      511       0
# 4           55.400002          5       57       0

# %%
# Broadcast.shape

# %%
Vessel = pd.read_csv(GDB_Folder + "Vessel.csv", sep=",")
Vessel.head(3)
# Out:
#         MMSI  IMO  CallSign  Name  VesselType  Length  Width  \
# 0  235469970  NaN       NaN   NaN        71.0   365.0   52.0
# 1  367000504  NaN       NaN   NaN        60.0    22.0    7.0
# 2  367870800  NaN       NaN   NaN        32.0    35.0   12.0
#
#   DimensionComponents
# 0       145,220,26,26
# 1           10,12,4,3
# 2            5,30,6,6

# %%
Vessel.rename(columns={'MMSI':'mmsi_id', 'Name':'vessel_name', 'IMO':'imo', 'CallSign':'call_sign', 'VesselType':'vessel_type', 'Length':'length', 'Width':'width'}, inplace=True)
Vessel.head(3)
# Out:
#      mmsi_id  imo  call_sign  vessel_name  vessel_type  length  width  \
# 0  235469970  NaN        NaN          NaN         71.0   365.0   52.0
# 1  367000504  NaN        NaN          NaN         60.0    22.0    7.0
# 2  367870800  NaN        NaN          NaN         32.0    35.0   12.0
#
#   DimensionComponents
# 0       145,220,26,26
# 1           10,12,4,3
# 2            5,30,6,6

# %%
# Extract Vessel Data
Vessel = Vessel[['mmsi_id', 'imo', 'call_sign', 'vessel_name', 'vessel_type','length', 'width']]
Vessel.head()
# Out:
#      mmsi_id  imo  call_sign  vessel_name  vessel_type  length  width
# 0  235469970  NaN        NaN          NaN         71.0   365.0   52.0
# 1  367000504  NaN        NaN          NaN         60.0    22.0    7.0
# 2  367870800  NaN        NaN          NaN         32.0    35.0   12.0
# 3  366281509  NaN        NaN          NaN         90.0    25.0    5.0
# 4  576110500  NaN        NaN          NaN         70.0   175.0   28.0

# %%
Voyage = pd.read_csv(GDB_Folder + "Voyage.csv", sep=",")
Voyage.head(3)
# Out:
#    VoyageID    Destination  Cargo  Draught                  ETA  \
# 0       337        OAKLAND     71      120  2014/01/02 07:30:00
# 1       232     SFO ANCH 9     32       45  2014/12/30 18:00:00
# 2       113  TIANJIN,CHINA     70       93  2014/01/21 06:00:00
#
#              StartTime              EndTime       MMSI
# 0  2014/01/01 00:00:00  2014/01/04 14:33:07  235469970
# 1  2014/01/01 00:00:00  2014/01/31 15:38:20  367870800
# 2  2014/01/01 00:00:04                  NaN  576110500

# %%
Voyage.rename(columns={'MMSI':'mmsi_id', 'VoyageID':'voyage_id', 'Draught':'draft', 'Cargo':'cargo'}, inplace=True)
Voyage.head(3)
# Out:
#    voyage_id    Destination  cargo  draft                  ETA  \
# 0        337        OAKLAND     71    120  2014/01/02 07:30:00
# 1        232     SFO ANCH 9     32     45  2014/12/30 18:00:00
# 2        113  TIANJIN,CHINA     70     93  2014/01/21 06:00:00
#
#              StartTime              EndTime    mmsi_id
# 0  2014/01/01 00:00:00  2014/01/04 14:33:07  235469970
# 1  2014/01/01 00:00:00  2014/01/31 15:38:20  367870800
# 2  2014/01/01 00:00:04                  NaN  576110500

# %%
# Extract Voyage Data
Voyage = Voyage[['mmsi_id', 'voyage_id', 'draft', 'cargo']]
Voyage.head()
# Out:
#      mmsi_id  voyage_id  draft  cargo
# 0  235469970        337    120     71
# 1  367870800        232     45     32
# 2  576110500        113     93     70
# 3  316004579        306     32     52
# 4  477221200        519     70     70

# %%
# Output result to csv
Broadcast.to_csv(OutputDir + "Broadcast.csv", index=False)
Vessel.to_csv(OutputDir + "Vessel.csv", index=False)
Voyage.to_csv(OutputDir + "Voyage.csv", index=False)
